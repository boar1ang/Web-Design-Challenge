# %%
import csv
import pandas as pd
import numpy as np
import time
from datetime import datetime 
# Output File (CSV)
output_data_file = "cities2.csv"

# %%
city_weather_df = pd.read_csv(output_data_file)
city_weather_df
# Out:
#      Unnamed: 0                     City  Temp.(F)  Max Temp.(F)  \
# 0             0                     Vila     49.19         54.00
# 1             1                   Laguna     56.19         61.00
# 2             2              George Town     80.33         82.40
# 3             3               Butaritari     84.20         84.20
# 4             4                 Hermanus     71.33         73.00
# ..          ...                      ...       ...           ...
# 533         533  Republic of El Salvador     83.03         89.60
# 534         534                  Aksarka      0.27          0.27
# 535         535                    Praia     80.60         80.60
# 536         536                    Ginir     62.51         62.51
# 537         537               Port Keats     82.78         82.78
#
#      Humidity (%)  Cloudiness  Wind Speed (mph)  Latitude  Longitude  \
# 0              76          40              2.24     42.03      -8.16
# ...

# %%
city_weather_df["Date"] = pd.to_datetime(city_weather_df["Date"], unit="s")
#city_weather_df["Date"] = city_weather_df["Date"].strftime('%Y-%m-%d')
city_weather_df
# Out:
#      Unnamed: 0                     City  Temp.(F)  Max Temp.(F)  \
# 0             0                     Vila     49.19         54.00
# 1             1                   Laguna     56.19         61.00
# 2             2              George Town     80.33         82.40
# 3             3               Butaritari     84.20         84.20
# 4             4                 Hermanus     71.33         73.00
# ..          ...                      ...       ...           ...
# 533         533  Republic of El Salvador     83.03         89.60
# 534         534                  Aksarka      0.27          0.27
# 535         535                    Praia     80.60         80.60
# 536         536                    Ginir     62.51         62.51
# 537         537               Port Keats     82.78         82.78
#
#      Humidity (%)  Cloudiness  Wind Speed (mph)  Latitude  Longitude  \
# 0              76          40              2.24     42.03      -8.16
# ...

# %%
city_weather_df.to_html("Resources/city_weather_table.html")
